# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("datafiles/cleaned_air_bnb_Jul_26.csv")
print(df.shape)
df.head()
# Out:
# (6136, 54)
#                                      url  \
# 0  https://www.airbnb.com/rooms/31573201
# 1  https://www.airbnb.com/rooms/38121290
# 2  https://www.airbnb.com/rooms/35701139
# 3  https://www.airbnb.com/rooms/48292462
# 4  https://www.airbnb.com/rooms/42577961
#
#                                                 name  numberOfGuests  \
# 0                           Avocado B&B and Cottages               4
# 1            Traditional Africa Mud House in Nairobi               2
# 2                                    A private house               2
# 3                                 BAS NGONG HOMESTAY               6
# 4  Art and life lovers community,We love life les...               3
#
#                            address                           roomType  \
# 0                     Ngong, Kenya  Private room in bed and breakfast
# 1   Nairobi, Nairobi County, Kenya       Private room in earthen home
# 2  Ngong, Wilaya ya Kajiado, Kenya         Shared room in rental unit
# ...

# %%
df.isnull().sum()
# Out:
# url                              0
# name                             0
# numberOfGuests                   0
# address                          0
# roomType                         0
# bathroomLabel                   26
# maxNights                        0
# minNights                        0
# localizedCheckInTimeWindow     730
# localizedCheckOutTime         1981
# city                           252
# localizedCity                    0
# state                          229
# latitude                         0
# longitude                        0
# price                            1
# hostId                           0
# memberSince                      0
# responseTime                  2327
# numberOfLanguages                0
# Washer                           0
# Shampoo                          0
# Hair dryer                       0
# Air conditioning                 0
# Private entrance               145
# numberOfBedsAvailable           53
# numberOfBedrooms                30
# ...

# %%
df.columns
# Out:
# Index(['url', 'name', 'numberOfGuests', 'address', 'roomType', 'bathroomLabel',
#        'maxNights', 'minNights', 'localizedCheckInTimeWindow',
#        'localizedCheckOutTime', 'city', 'localizedCity', 'state', 'latitude',
#        'longitude', 'price', 'hostId', 'memberSince', 'responseTime',
#        'numberOfLanguages', 'Washer', 'Shampoo', 'Hair dryer',
#        'Air conditioning', 'Private entrance', 'numberOfBedsAvailable',
#        'numberOfBedrooms', 'double_bed', 'floor_mattress', 'single_bed',
#        'queen_bed', 'couch', 'king_bed', 'air_mattress', 'sofa_bed',
#        'small_double_bed', 'bunk_bed', 'toddler_bed', 'crib', 'hammock',
#        'water_bed', 'allowsChildren', 'allowsEvents', 'allowsPets',
#        'allowsSmoking', 'allowsInfants', 'personCapacity', 'Accuracy',
#        'Check-in', 'Cleanliness', 'Communication', 'Location', 'Review Count',
#        'Value'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6136 entries, 0 to 6135
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   url                         6136 non-null   object
#  1   name                        6136 non-null   object
#  2   numberOfGuests              6136 non-null   int64
#  3   address                     6136 non-null   object
#  4   roomType                    6136 non-null   object
#  5   bathroomLabel               6110 non-null   object
#  6   maxNights                   6136 non-null   int64
#  7   minNights                   6136 non-null   int64
#  8   localizedCheckInTimeWindow  5406 non-null   object
#  9   localizedCheckOutTime       4155 non-null   object
#  10  city                        5884 non-null   object
#  11  localizedCity               6136 non-null   object
#  12  state                       5907 non-null   object
# ...

# %%
df.describe()
# Out:
#        numberOfGuests    maxNights    minNights     latitude    longitude  \
# count     6136.000000  6136.000000  6136.000000  6136.000000  6136.000000
# mean         4.071545   765.087516     2.743644    -1.837330    37.540036
# std          3.002080   447.448872    18.704635     1.405421     1.574521
# min          1.000000     1.000000     1.000000    -4.658410    34.007630
# 25%          2.000000   365.000000     1.000000    -3.341803    36.782373
# 50%          3.000000  1125.000000     1.000000    -1.293850    36.850645
# 75%          5.000000  1125.000000     2.000000    -1.214853    39.581283
# max         16.000000  3655.000000   999.000000     2.379670    40.166640
#
#               price        hostId  numberOfLanguages  numberOfBedsAvailable  \
# count   6135.000000  6.136000e+03        6136.000000            6083.000000
# mean      89.512958  2.350865e+08           0.673892               2.580306
# ...

# %%
plt.hist(df.price)
# Out:
# (array([6.102e+03, 1.900e+01, 9.000e+00, 1.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 0.000e+00, 2.000e+00, 2.000e+00]),
#  array([   10.,  1009.,  2008.,  3007.,  4006.,  5005.,  6004.,  7003.,
#          8002.,  9001., 10000.]),
#  <BarContainer object of 10 artists>)

# %%
df.describe(include=object)
# Out:
#                                           url                 name  \
# count                                    6136                 6136
# unique                                   6136                 6043
# top     https://www.airbnb.com/rooms/31573201  Home away from home
# freq                                        1                   19
#
#                                address            roomType bathroomLabel  \
# count                             6136                6136          6110
# unique                             511                  92            65
# top     Nairobi, Nairobi County, Kenya  Entire rental unit        1 bath
# freq                              2280                1881          1923
#
#        localizedCheckInTimeWindow localizedCheckOutTime     city  \
# count                        5406                  4155     5884
# unique                        132                    23      295
# ...

# %% [markdown]
# # 1 : Common room types in data set

# %%
##  Common room types in data set

# Count the occurrences of each unique value in the 'roomType' column
room_type_counts = df['roomType'].value_counts()

# Increase figure size
plt.figure(figsize=(20, 6))

# Create a bar chart
plt.bar(room_type_counts.index, room_type_counts.values)

# Add labels and title
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.title('Count of Each Unique Room Type')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=90)

# Display the plot
plt.show()


# Display the plot
plt.tight_layout()  # Ensures labels fit within the figure area
plt.show()

# %%
## Taking only fewer room types

# Count the occurrences of each unique value in the 'roomType' column
room_type_counts = df['roomType'].value_counts()

# Select the top 20 room types
top_room_types = room_type_counts.head(20)

# Increase figure size
plt.figure(figsize=(20, 6))

# Create a bar chart
plt.bar(top_room_types.index, top_room_types.values)

# Add labels and title
plt.xlabel('Room Type')
plt.ylabel('Count')
plt.title('Count of Top 20 Room Types')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45)

# Display the plot
plt.tight_layout()  # Ensures labels fit within the figure area
plt.show()

# %% [markdown]
# # 2 :  Prices varying across room types

# %%
## Prices varying across room types

# Create a box plot or violin plot
plt.figure(figsize=(20, 6))  # Set figure size
sns.set(style="whitegrid")  # Set plot style

# Choose either box plot or violin plot by uncommenting the appropriate line
#sns.boxplot(x="roomType", y="price", data=df)  # Box plot
sns.violinplot(x="roomType", y="price", data=df)  # Violin plot

# Add labels and title
plt.xlabel('Room Type')
plt.ylabel('Price')
plt.title('Comparison of Prices for Each Room Type')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=90)

# Display the plot
plt.show()

# %% [markdown]
# # 3 :  Avg price for each city

# %%
df.columns
# Out:
# Index(['url', 'name', 'numberOfGuests', 'address', 'roomType', 'bathroomLabel',
#        'maxNights', 'minNights', 'localizedCheckInTimeWindow',
#        'localizedCheckOutTime', 'city', 'localizedCity', 'state', 'latitude',
#        'longitude', 'price', 'hostId', 'memberSince', 'responseTime',
#        'numberOfLanguages', 'Washer', 'Shampoo', 'Hair dryer',
#        'Air conditioning', 'Private entrance', 'numberOfBedsAvailable',
#        'numberOfBedrooms', 'double_bed', 'floor_mattress', 'single_bed',
#        'queen_bed', 'couch', 'king_bed', 'air_mattress', 'sofa_bed',
#        'small_double_bed', 'bunk_bed', 'toddler_bed', 'crib', 'hammock',
#        'water_bed', 'allowsChildren', 'allowsEvents', 'allowsPets',
#        'allowsSmoking', 'allowsInfants', 'personCapacity', 'Accuracy',
#        'Check-in', 'Cleanliness', 'Communication', 'Location', 'Review Count',
#        'Value'],
#       dtype='object')

# %%
# Group data by City and calculate the average price
average_prices = df.groupby("city")["price"].mean().reset_index()

# Create a bar chart using matplotlib
plt.figure(figsize=(20, 6))
plt.bar(average_prices["city"], average_prices["price"], color='skyblue')
plt.xlabel("city")
plt.ylabel("Average Price")
plt.title("Average Prices for Each City (Bar Chart)")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# Create a box plot using seaborn
plt.figure(figsize=(20, 6))
sns.boxplot(x="city", y="price", data=df, palette="Set3")
plt.xlabel("City")
plt.ylabel("Price")
plt.title("Distribution of Prices by City (Box Plot)")
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1772/3897246411.py:11: UserWarning: Glyph 20869 (\N{CJK UNIFIED IDEOGRAPH-5185}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1772/3897246411.py:11: UserWarning: Glyph 32599 (\N{CJK UNIFIED IDEOGRAPH-7F57}) missing from current font.
#   plt.tight_layout()
# /tmp/ipykernel_1772/3897246411.py:11: UserWarning: Glyph 27605 (\N{CJK UNIFIED IDEOGRAPH-6BD5}) missing from current font.
#   plt.tight_layout()
# /config/workspace/venv/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 20869 (\N{CJK UNIFIED IDEOGRAPH-5185}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /config/workspace/venv/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 32599 (\N{CJK UNIFIED IDEOGRAPH-7F57}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...

# %% [markdown]
# # 4 :  Host response time vs price

# %%
# Group data by responseTime and calculate the average price
average_prices = df.groupby("responseTime")["price"].mean().reset_index()

# Create a bar chart using matplotlib
plt.figure(figsize=(10, 6))
plt.bar(average_prices["responseTime"], average_prices["price"], color='skyblue')
plt.xlabel("Response Time")
plt.ylabel("Average Price")
plt.title("Average Prices for Each Response Time (Bar Chart)")
plt.xticks(average_prices["responseTime"])
plt.tight_layout()
plt.show()

# Create a box plot using seaborn
plt.figure(figsize=(10, 6))
sns.boxplot(x="responseTime", y="price", data=df, palette="Set3")
plt.xlabel("Response Time")
plt.ylabel("Price")
plt.title("Distribution of Prices by Response Time (Box Plot)")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 5 : Number of guests frequency

# %%
# Create a histogram using matplotlib
plt.figure(figsize=(10, 6))
plt.hist(df['numberOfGuests'], bins=10, color='skyblue', edgecolor='black')
plt.xlabel("Number of Guests")
plt.ylabel("Frequency")
plt.title("Histogram of Number of Guests")
plt.tight_layout()
plt.show()

# Create a bar chart using matplotlib
guest_counts = df['numberOfGuests'].value_counts().sort_index()
plt.figure(figsize=(10, 6))
plt.bar(guest_counts.index, guest_counts.values, color='skyblue')
plt.xlabel("Number of Guests")
plt.ylabel("Frequency")
plt.title("Bar Chart of Number of Guests")
plt.xticks(guest_counts.index)
plt.tight_layout()
plt.show()

# %% [markdown]
# # 6 : Price vs review counts

# %%
# Create a box plot to identify outliers in the 'price' column
plt.figure(figsize=(8, 6))
plt.boxplot(df['price'], vert=False)
plt.xlabel("Price")
plt.title("Box Plot of Price to Identify Outliers")
plt.tight_layout()
plt.show()

# Create a box plot to identify outliers in the 'Review Count' column
plt.figure(figsize=(8, 6))
plt.boxplot(df['Review Count'], vert=False)
plt.xlabel("Review Count")
plt.title("Box Plot of Review Count to Identify Outliers")
plt.tight_layout()
plt.show()

# Create a scatter plot to visualize the relationship between 'price' and 'Review Count'
plt.figure(figsize=(8, 6))
plt.scatter(df['price'], df['Review Count'], color='skyblue')
plt.xlabel("Price")
plt.ylabel("Review Count")
plt.title("Scatter Plot of Price vs. Review Count")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 7 : MaxNight vs MinNight

# %%
# Create a scatter plot of 'price' against 'maxNights'
plt.figure(figsize=(8, 6))
plt.scatter(df['maxNights'], df['price'], color='skyblue')
plt.xlabel("Max Nights")
plt.ylabel("Price")
plt.title("Scatter Plot of Price vs. Max Nights")
plt.tight_layout()
plt.show()

# Create a scatter plot of 'price' against 'minNights'
plt.figure(figsize=(8, 6))
plt.scatter(df['minNights'], df['price'], color='skyblue')
plt.xlabel("Min Nights")
plt.ylabel("Price")
plt.title("Scatter Plot of Price vs. Min Nights")
plt.tight_layout()
plt.show()

# Create a line plot of 'price' against 'maxNights'
plt.figure(figsize=(8, 6))
plt.plot(df['maxNights'], df['price'], marker='o')
plt.xlabel("Max Nights")
plt.ylabel("Price")
plt.title("Line Plot of Price vs. Max Nights")
plt.tight_layout()
plt.show()

# Create a line plot of 'price' against 'minNights'
plt.figure(figsize=(8, 6))
plt.plot(df['minNights'], df['price'], marker='o')
plt.xlabel("Min Nights")
plt.ylabel("Price")
plt.title("Line Plot of Price vs. Min Nights")
plt.tight_layout()
plt.show()

# %% [markdown]
# # 8 : Person capacity vs Number of bedrooms

# %%
# Create a scatter plot of 'personCapacity' against 'numberOfBedsAvailable'
plt.figure(figsize=(8, 6))
plt.scatter(df['personCapacity'], df['numberOfBedsAvailable'], color='skyblue')
plt.xlabel("Person Capacity")
plt.ylabel("Number of Beds Available")
plt.title("Scatter Plot: Person Capacity vs. Number of Beds Available")
plt.tight_layout()
plt.show()

# Group data by 'personCapacity' and calculate the average 'numberOfBedsAvailable'
average_beds = df.groupby("personCapacity")["numberOfBedsAvailable"].mean().reset_index()

# Create a bar chart to compare average 'numberOfBedsAvailable' by 'personCapacity'
plt.figure(figsize=(10, 6))
plt.bar(average_beds["personCapacity"], average_beds["numberOfBedsAvailable"], color='skyblue')
plt.xlabel("Person Capacity")
plt.ylabel("Average Number of Beds Available")
plt.title("Bar Chart: Average Number of Beds Available by Person Capacity")
plt.xticks(average_beds["personCapacity"])
plt.tight_layout()
plt.show()

# %% [markdown]
# # 10 : Lattitudes and Longitudes vs Price

# %%
# Create a scatter plot of 'latitude' against 'price'
plt.figure(figsize=(10, 6))
plt.scatter(df['latitude'], df['price'], color='skyblue')
plt.xlabel("Latitude")
plt.ylabel("Price")
plt.title("Scatter Plot: Latitude vs. Price")
plt.tight_layout()
plt.show()

# Create a scatter plot of 'longitude' against 'price'
plt.figure(figsize=(10, 6))
plt.scatter(df['longitude'], df['price'], color='skyblue')
plt.xlabel("Longitude")
plt.ylabel("Price")
plt.title("Scatter Plot: Longitude vs. Price")
plt.tight_layout()
plt.show()
